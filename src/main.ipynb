# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from recommenders import ClusteringBasedRecommender, Data
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, SpectralClustering, OPTICS, Birch
from sklearn.preprocessing import Normalizer, StandardScaler, MinMaxScaler, PolynomialFeatures
from sklearn.impute import SimpleImputer, KNNImputer

# %%
import random 
def test_error(epochs, recommender,data:Data, seed=196, sample_size=1000):
    random.seed(seed)
    rand_seeds = [random.randint(0, 1000) for _ in range(epochs)]
    avg_error = 0
    for i in range(epochs):
        test_data = data.test_data.sample(n=sample_size, random_state=rand_seeds[i])
        test_data['predicted_rating'] = test_data.apply(
            lambda row: recommender.predict(int(row['userId']), int(row['movieId'])), axis=1
            )
        avg_error += np.mean(np.abs(test_data['rating'] - test_data['predicted_rating']))
    return avg_error / epochs

# %%
imputers = [SimpleImputer(strategy='mean'),
            SimpleImputer(strategy='median'),
            KNNImputer(n_neighbors=4, weights='uniform')]
preprocessors = [[], [MinMaxScaler()],
                 [StandardScaler()], [Normalizer()],
                 [MinMaxScaler(), StandardScaler()],
                 [MinMaxScaler(), Normalizer()],
                 [StandardScaler(), Normalizer()]]
clusterers = [KMeans(n_clusters=20), 
              DBSCAN(eps=0.5, min_samples=5),
              AgglomerativeClustering(n_clusters=20),
              SpectralClustering(n_clusters=20),
              OPTICS(min_samples=5),
              Birch(n_clusters=10)]
errors = {}

for i,imputer in enumerate(tqdm(imputers)):
    for preprocessor in preprocessors:
        for clusterer in clusterers:
            data = Data('ml-latest-small', 
                        imputer=imputer,
                        preprocessors=preprocessor)

            recommender = ClusteringBasedRecommender(
                data=data.train_data_table_for_clustering_normalized,
                data_unnormalized=data.train_data_table_for_clustering,
                movie_genres=data.movie_genres,
                clusterer=clusterer
                )
            recommender.train()
            errors[(imputer, tuple(preprocessor), clusterer)] = test_error(2, recommender,data,2, sample_size=100)
# Out:
#  43%|████▎     | 3/7 [00:12<00:16,  4.12s/it]c:\Users\Robert\.pyenv\pyenv-win\versions\3.12.2\Lib\site-packages\sklearn\cluster\_birch.py:725: ConvergenceWarning: Number of subclusters found (1) by BIRCH is less than (10). Decrease the threshold.
#   warnings.warn(
#  71%|███████▏  | 5/7 [00:20<00:08,  4.05s/it]c:\Users\Robert\.pyenv\pyenv-win\versions\3.12.2\Lib\site-packages\sklearn\cluster\_birch.py:725: ConvergenceWarning: Number of subclusters found (1) by BIRCH is less than (10). Decrease the threshold.
#   warnings.warn(
# 100%|██████████| 7/7 [00:28<00:00,  4.08s/it]
#  43%|████▎     | 3/7 [00:12<00:16,  4.13s/it]c:\Users\Robert\.pyenv\pyenv-win\versions\3.12.2\Lib\site-packages\sklearn\cluster\_birch.py:725: ConvergenceWarning: Number of subclusters found (1) by BIRCH is less than (10). Decrease the threshold.
#   warnings.warn(
#  71%|███████▏  | 5/7 [00:20<00:08,  4.13s/it]c:\Users\Robert\.pyenv\pyenv-win\versions\3.12.2\Lib\site-packages\sklearn\cluster\_birch.py:725: ConvergenceWarning: Number of subclusters found (1) by BIRCH is less than (10). Decrease the threshold.
#   warnings.warn(
# 100%|██████████| 7/7 [00:28<00:00,  4.13s/it]
#  43%|████▎     | 3/7 [00:12<00:16,  4.23s/it]c:\Users\Robert\.pyenv\pyenv-win\versions\3.12.2\Lib\site-packages\sklearn\cluster\_birch.py:725: ConvergenceWarning: Number of subclusters found (1) by BIRCH is less than (10). Decrease the threshold.
#   warnings.warn(
#  71%|███████▏  | 5/7 [00:21<00:08,  4.23s/it]c:\Users\Robert\.pyenv\pyenv-win\versions\3.12.2\Lib\site-packages\sklearn\cluster\_birch.py:725: ConvergenceWarning: Number of subclusters found (1) by BIRCH is less than (10). Decrease the threshold.
#   warnings.warn(
# 100%|██████████| 7/7 [00:29<00:00,  4.24s/it]

# %%
print("average error when predicting ratings:")
for key, value in sorted(errors.items(), key=lambda x: x[1]):
    print(value, key)
# Out:
# average error when predicting ratings:
# 0.6668205613686213 (SimpleImputer(strategy='median'), (), KMeans(n_clusters=20))
# 0.6691391529062851 (SimpleImputer(strategy='median'), (), AgglomerativeClustering(n_clusters=20))
# 0.6730680179011717 (SimpleImputer(), (MinMaxScaler(),), KMeans(n_clusters=20))
# 0.6745119889146399 (SimpleImputer(), (), KMeans(n_clusters=20))
# 0.6752099335807624 (SimpleImputer(strategy='median'), (StandardScaler(), Normalizer()), SpectralClustering(n_clusters=20))
# 0.6761412865641284 (SimpleImputer(strategy='median'), (MinMaxScaler(),), AgglomerativeClustering(n_clusters=20))
# 0.6768241960831751 (SimpleImputer(), (), Birch(n_clusters=10))
# 0.6792811418060363 (KNNImputer(n_neighbors=4), (StandardScaler(), Normalizer()), AgglomerativeClustering(n_clusters=20))
# 0.680371007312158 (SimpleImputer(strategy='median'), (MinMaxScaler(),), KMeans(n_clusters=20))
# 0.6806867398047693 (SimpleImputer(strategy='median'), (StandardScaler(), Normalizer()), AgglomerativeClustering(n_clusters=20))
# 0.6822060947333347 (KNNImputer(n_neighbors=4), (MinMaxScaler(),), AgglomerativeClustering(n_clusters=20))
# 0.6829782479283365 (SimpleImputer(strategy='median'), (StandardScaler(),), KMeans(n_clusters=20))
# 0.6837138567904506 (SimpleImputer(), (StandardScaler(), Normalizer()), AgglomerativeClustering(n_clusters=20))
# 0.6844274344314596 (KNNImputer(n_neighbors=4), (), KMeans(n_clusters=20))
# 0.6851389429732488 (KNNImputer(n_neighbors=4), (), AgglomerativeClustering(n_clusters=20))
# 0.6859492139707083 (SimpleImputer(), (StandardScaler(), Normalizer()), KMeans(n_clusters=20))
# 0.6864445874652114 (SimpleImputer(strategy='median'), (StandardScaler(), Normalizer()), KMeans(n_clusters=20))
# 0.6868689658885418 (SimpleImputer(), (MinMaxScaler(), StandardScaler()), KMeans(n_clusters=20))
# 0.6875957864776712 (KNNImputer(n_neighbors=4), (StandardScaler(), Normalizer()), Birch(n_clusters=10))
# 0.6885725295121063 (SimpleImputer(strategy='median'), (StandardScaler(),), AgglomerativeClustering(n_clusters=20))
# 0.6885725295121063 (SimpleImputer(strategy='median'), (MinMaxScaler(), StandardScaler()), AgglomerativeClustering(n_clusters=20))
# 0.6886292772929055 (KNNImputer(n_neighbors=4), (StandardScaler(),), KMeans(n_clusters=20))
# 0.6887493334379334 (KNNImputer(n_neighbors=4), (StandardScaler(), Normalizer()), KMeans(n_clusters=20))
# 0.688770245558872 (KNNImputer(n_neighbors=4), (StandardScaler(),), AgglomerativeClustering(n_clusters=20))
# 0.688770245558872 (KNNImputer(n_neighbors=4), (MinMaxScaler(), StandardScaler()), AgglomerativeClustering(n_clusters=20))
# 0.6898859579683874 (KNNImputer(n_neighbors=4), (StandardScaler(), Normalizer()), SpectralClustering(n_clusters=20))
# 0.6900305099936442 (KNNImputer(n_neighbors=4), (MinMaxScaler(),), KMeans(n_clusters=20))
# 0.6912448339406424 (SimpleImputer(), (StandardScaler(),), AgglomerativeClustering(n_clusters=20))
# 0.6912448339406424 (SimpleImputer(), (MinMaxScaler(), StandardScaler()), AgglomerativeClustering(n_clusters=20))
# 0.6922070432508917 (KNNImputer(n_neighbors=4), (StandardScaler(),), Birch(n_clusters=10))
# 0.6922070432508917 (KNNImputer(n_neighbors=4), (MinMaxScaler(), StandardScaler()), Birch(n_clusters=10))
# 0.6934905528211088 (SimpleImputer(strategy='median'), (StandardScaler(), Normalizer()), Birch(n_clusters=10))
# 0.6936457317616675 (SimpleImputer(strategy='median'), (MinMaxScaler(), StandardScaler()), KMeans(n_clusters=20))
# 0.6941152966446068 (SimpleImputer(), (StandardScaler(), Normalizer()), Birch(n_clusters=10))
# 0.6946689273838451 (SimpleImputer(), (MinMaxScaler(),), AgglomerativeClustering(n_clusters=20))
# 0.6952899064140361 (SimpleImputer(), (), AgglomerativeClustering(n_clusters=20))
# 0.6963736274326415 (SimpleImputer(strategy='median'), (), Birch(n_clusters=10))
# 0.6977152399235838 (KNNImputer(n_neighbors=4), (MinMaxScaler(), StandardScaler()), KMeans(n_clusters=20))
# 0.6977925000542184 (KNNImputer(n_neighbors=4), (), Birch(n_clusters=10))
# 0.7001823699017322 (SimpleImputer(), (StandardScaler(),), KMeans(n_clusters=20))
# 0.7031258174468029 (SimpleImputer(strategy='median'), (StandardScaler(),), Birch(n_clusters=10))
# 0.7031258174468029 (SimpleImputer(strategy='median'), (MinMaxScaler(), StandardScaler()), Birch(n_clusters=10))
# 0.7035515538223622 (KNNImputer(n_neighbors=4), (MinMaxScaler(),), Birch(n_clusters=10))
# 0.7062393941691936 (SimpleImputer(), (StandardScaler(), Normalizer()), SpectralClustering(n_clusters=20))
# 0.7077266507307698 (SimpleImputer(), (StandardScaler(),), Birch(n_clusters=10))
# 0.7077266507307698 (SimpleImputer(), (MinMaxScaler(), StandardScaler()), Birch(n_clusters=10))
# 0.7180345620097595 (SimpleImputer(strategy='median'), (MinMaxScaler(), Normalizer()), KMeans(n_clusters=20))
# 0.7237490804791744 (SimpleImputer(), (MinMaxScaler(),), SpectralClustering(n_clusters=20))
# 0.7280538081625292 (KNNImputer(n_neighbors=4), (MinMaxScaler(),), SpectralClustering(n_clusters=20))
# 0.7285807699794988 (SimpleImputer(strategy='median'), (Normalizer(),), KMeans(n_clusters=20))
# 0.7294794451071384 (SimpleImputer(), (Normalizer(),), KMeans(n_clusters=20))
# 0.7296798265348896 (KNNImputer(n_neighbors=4), (StandardScaler(), Normalizer()), DBSCAN())
# 0.734973836803261 (SimpleImputer(), (StandardScaler(), Normalizer()), DBSCAN())
# 0.7350925722565251 (SimpleImputer(strategy='median'), (StandardScaler(), Normalizer()), DBSCAN())
# 0.737852440525834 (SimpleImputer(), (MinMaxScaler(), Normalizer()), KMeans(n_clusters=20))
# 0.7390698251873145 (KNNImputer(n_neighbors=4), (MinMaxScaler(), Normalizer()), KMeans(n_clusters=20))
# 0.7418908981148402 (SimpleImputer(strategy='median'), (MinMaxScaler(),), SpectralClustering(n_clusters=20))
# 0.7422601575006464 (SimpleImputer(), (MinMaxScaler(), Normalizer()), AgglomerativeClustering(n_clusters=20))
# 0.7430329870030612 (SimpleImputer(), (Normalizer(),), SpectralClustering(n_clusters=20))
# 0.7465333187131664 (SimpleImputer(), (Normalizer(),), AgglomerativeClustering(n_clusters=20))
# 0.7541839385562957 (SimpleImputer(strategy='median'), (Normalizer(),), AgglomerativeClustering(n_clusters=20))
# 0.7555604035137564 (SimpleImputer(strategy='median'), (MinMaxScaler(), Normalizer()), AgglomerativeClustering(n_clusters=20))
# 0.7590581879415286 (KNNImputer(n_neighbors=4), (MinMaxScaler(), StandardScaler()), OPTICS())
# 0.7593295160439648 (SimpleImputer(strategy='median'), (StandardScaler(),), SpectralClustering(n_clusters=20))
# 0.7595415567259018 (SimpleImputer(), (MinMaxScaler(), Normalizer()), SpectralClustering(n_clusters=20))
# 0.7600003933650602 (KNNImputer(n_neighbors=4), (Normalizer(),), KMeans(n_clusters=20))
# 0.7603516090525595 (SimpleImputer(), (StandardScaler(),), SpectralClustering(n_clusters=20))
# 0.7603659313732345 (SimpleImputer(strategy='median'), (MinMaxScaler(), StandardScaler()), SpectralClustering(n_clusters=20))
# 0.7607938796310281 (SimpleImputer(), (MinMaxScaler(), StandardScaler()), SpectralClustering(n_clusters=20))
# 0.7609772486297754 (SimpleImputer(), (MinMaxScaler(),), Birch(n_clusters=10))
# 0.7619877271197603 (KNNImputer(n_neighbors=4), (), OPTICS())
# 0.7620823736698814 (SimpleImputer(strategy='median'), (MinMaxScaler(),), Birch(n_clusters=10))
# 0.7622251110017838 (KNNImputer(n_neighbors=4), (StandardScaler(), Normalizer()), OPTICS())
# 0.765506875034845 (SimpleImputer(strategy='median'), (Normalizer(),), SpectralClustering(n_clusters=20))
# 0.7662760653226611 (SimpleImputer(), (StandardScaler(), Normalizer()), OPTICS())
# 0.7665442455502354 (SimpleImputer(strategy='median'), (StandardScaler(), Normalizer()), OPTICS())
# 0.7690882521906759 (KNNImputer(n_neighbors=4), (Normalizer(),), SpectralClustering(n_clusters=20))
# 0.7770983803135378 (KNNImputer(n_neighbors=4), (MinMaxScaler(), Normalizer()), AgglomerativeClustering(n_clusters=20))
# 0.7788545006855515 (KNNImputer(n_neighbors=4), (Normalizer(),), AgglomerativeClustering(n_clusters=20))
# 0.7810155075334195 (KNNImputer(n_neighbors=4), (MinMaxScaler(), Normalizer()), SpectralClustering(n_clusters=20))
# 0.7815552547036007 (SimpleImputer(strategy='median'), (), OPTICS())
# 0.7841714079880217 (SimpleImputer(), (MinMaxScaler(), StandardScaler()), OPTICS())
# 0.7871240564122 (KNNImputer(n_neighbors=4), (StandardScaler(),), OPTICS())
# 0.7876264383534071 (SimpleImputer(strategy='median'), (MinMaxScaler(), Normalizer()), SpectralClustering(n_clusters=20))
# 0.787861793787354 (SimpleImputer(), (StandardScaler(),), OPTICS())
# 0.7886188029612171 (SimpleImputer(), (Normalizer(),), OPTICS())
# 0.7887829102925673 (SimpleImputer(strategy='median'), (MinMaxScaler(), Normalizer()), OPTICS())
# 0.789144059715332 (SimpleImputer(), (MinMaxScaler(), Normalizer()), OPTICS())
# 0.7911474591824446 (SimpleImputer(strategy='median'), (), DBSCAN())
# 0.7911474591824446 (SimpleImputer(strategy='median'), (StandardScaler(),), DBSCAN())
# 0.7911474591824446 (SimpleImputer(strategy='median'), (StandardScaler(),), OPTICS())
# 0.7911474591824446 (SimpleImputer(strategy='median'), (Normalizer(),), DBSCAN())
# 0.7911474591824446 (SimpleImputer(strategy='median'), (Normalizer(),), Birch(n_clusters=10))
# 0.7911474591824446 (SimpleImputer(strategy='median'), (MinMaxScaler(), StandardScaler()), DBSCAN())
# 0.7911474591824446 (SimpleImputer(strategy='median'), (MinMaxScaler(), StandardScaler()), OPTICS())
# 0.7911474591824446 (SimpleImputer(strategy='median'), (MinMaxScaler(), Normalizer()), Birch(n_clusters=10))
# 0.7912594222158469 (SimpleImputer(strategy='median'), (MinMaxScaler(), Normalizer()), DBSCAN())
# 0.7913877111138262 (KNNImputer(n_neighbors=4), (), DBSCAN())
# 0.7913877111138262 (KNNImputer(n_neighbors=4), (StandardScaler(),), DBSCAN())
# 0.7913877111138262 (KNNImputer(n_neighbors=4), (Normalizer(),), DBSCAN())
# 0.7913877111138262 (KNNImputer(n_neighbors=4), (Normalizer(),), Birch(n_clusters=10))
# 0.7913877111138262 (KNNImputer(n_neighbors=4), (MinMaxScaler(), StandardScaler()), DBSCAN())
# 0.7913877111138262 (KNNImputer(n_neighbors=4), (MinMaxScaler(), Normalizer()), Birch(n_clusters=10))
# 0.7915821205458592 (KNNImputer(n_neighbors=4), (MinMaxScaler(), Normalizer()), DBSCAN())
# 0.7917806958830316 (SimpleImputer(), (), DBSCAN())
# 0.7917806958830316 (SimpleImputer(), (), OPTICS())
# 0.7917806958830316 (SimpleImputer(), (MinMaxScaler(),), OPTICS())
# 0.7917806958830316 (SimpleImputer(), (StandardScaler(),), DBSCAN())
# 0.7917806958830316 (SimpleImputer(), (Normalizer(),), DBSCAN())
# 0.7917806958830316 (SimpleImputer(), (Normalizer(),), Birch(n_clusters=10))
# 0.7917806958830316 (SimpleImputer(), (MinMaxScaler(), StandardScaler()), DBSCAN())
# 0.7917806958830316 (SimpleImputer(), (MinMaxScaler(), Normalizer()), Birch(n_clusters=10))
# 0.7918965550907899 (SimpleImputer(), (MinMaxScaler(), Normalizer()), DBSCAN())
# 0.793799914765743 (KNNImputer(n_neighbors=4), (StandardScaler(),), SpectralClustering(n_clusters=20))
# 0.793799914765743 (KNNImputer(n_neighbors=4), (MinMaxScaler(), StandardScaler()), SpectralClustering(n_clusters=20))
# 0.7942570235668597 (KNNImputer(n_neighbors=4), (MinMaxScaler(), Normalizer()), OPTICS())
# 0.7944353892841343 (SimpleImputer(strategy='median'), (MinMaxScaler(),), OPTICS())
# 0.7945614458329366 (KNNImputer(n_neighbors=4), (MinMaxScaler(),), OPTICS())
# 0.7949788727092953 (KNNImputer(n_neighbors=4), (Normalizer(),), OPTICS())
# 0.795649227023632 (SimpleImputer(strategy='median'), (), SpectralClustering(n_clusters=20))
# 0.8010194160853623 (SimpleImputer(), (MinMaxScaler(),), DBSCAN())
# 0.8022796400880636 (SimpleImputer(), (), SpectralClustering(n_clusters=20))
# 0.8030280511951324 (SimpleImputer(strategy='median'), (MinMaxScaler(),), DBSCAN())
# 0.8036423656121521 (SimpleImputer(strategy='median'), (Normalizer(),), OPTICS())
# 0.8054328382377234 (KNNImputer(n_neighbors=4), (), SpectralClustering(n_clusters=20))
# 0.8093125171854998 (KNNImputer(n_neighbors=4), (MinMaxScaler(),), DBSCAN())
